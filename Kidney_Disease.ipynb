# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('kidney_disease.csv')

# %%
df.sample(10)
# Out:
#       id   age     bp     sg   al   su       rbc        pc         pcc  \
# 45    45  54.0   80.0  1.020  3.0  0.0       NaN  abnormal  notpresent
# 39    39  82.0   80.0  1.010  2.0  2.0    normal       NaN  notpresent
# 107  107  55.0  100.0  1.015  1.0  4.0    normal       NaN  notpresent
# 74    74  56.0   90.0  1.015  2.0  0.0  abnormal  abnormal  notpresent
# 194  194  80.0   70.0  1.010  2.0  NaN       NaN  abnormal  notpresent
# 342  342  44.0   60.0  1.020  0.0  0.0    normal    normal  notpresent
# 94    94  65.0   70.0  1.010  0.0  0.0       NaN    normal  notpresent
# 385  385  63.0   70.0  1.020  0.0  0.0    normal    normal  notpresent
# 332  332  34.0   70.0  1.025  0.0  0.0    normal    normal  notpresent
# 174  174  54.0   70.0    NaN  NaN  NaN       NaN       NaN  notpresent
#
#              ba  ...  pcv     wc   rc  htn     dm  cad appet   pe ane  \
# 45   notpresent  ...  NaN    NaN  NaN  yes    yes   no  poor  yes  no
# ...

# %%
df.shape
# Out:
# (400, 26)

# %%
df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 26 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              400 non-null    int64
#  1   age             391 non-null    float64
#  2   bp              388 non-null    float64
#  3   sg              353 non-null    float64
#  4   al              354 non-null    float64
#  5   su              351 non-null    float64
#  6   rbc             248 non-null    object
#  7   pc              335 non-null    object
#  8   pcc             396 non-null    object
#  9   ba              396 non-null    object
#  10  bgr             356 non-null    float64
#  11  bu              381 non-null    float64
#  12  sc              383 non-null    float64
#  13  sod             313 non-null    float64
#  14  pot             312 non-null    float64
#  15  hemo            348 non-null    float64
#  16  pcv             330 non-null    object
# ...

# %%
df.columns
# Out:
# Index(['id', 'age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr',
#        'bu', 'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.drop('id', axis = 1,inplace = True)

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df.sample()
# Out:
#       age    bp    sg   al   su  rbc      pc         pcc          ba    bgr  \
# 111  65.0  80.0  1.01  3.0  3.0  NaN  normal  notpresent  notpresent  294.0
#
#      ...  pcv    wc   rc  htn   dm  cad appet  pe ane classification
# 111  ...   32  9000  3.9  yes  yes  yes  good  no  no            ckd
#
# [1 rows x 25 columns]

# %%
df.describe()
# Out:
#               age          bp          sg          al          su         bgr  \
# count  391.000000  388.000000  353.000000  354.000000  351.000000  356.000000
# mean    51.483376   76.469072    1.017408    1.016949    0.450142  148.036517
# std     17.169714   13.683637    0.005717    1.352679    1.099191   79.281714
# min      2.000000   50.000000    1.005000    0.000000    0.000000   22.000000
# 25%     42.000000   70.000000    1.010000    0.000000    0.000000   99.000000
# 50%     55.000000   80.000000    1.020000    0.000000    0.000000  121.000000
# 75%     64.500000   80.000000    1.020000    2.000000    0.000000  163.000000
# max     90.000000  180.000000    1.025000    5.000000    5.000000  490.000000
#
#                bu          sc         sod         pot        hemo
# count  381.000000  383.000000  313.000000  312.000000  348.000000
# mean    57.425722    3.072454  137.528754    4.627244   12.526437
# std     50.503006    5.741126   10.408752    3.193904    2.912587
# ...

# %%
df['pcv']
# Out:
# 0      44
# 1      38
# 2      31
# 3      32
# 4      35
#        ..
# 395    47
# 396    54
# 397    49
# 398    51
# 399    53
# Name: pcv, Length: 400, dtype: object

# %%
df['pcv'].unique()
# Out:
# array(['44', '38', '31', '32', '35', '39', '36', '33', '29', '28', nan,
#        '16', '24', '37', '30', '34', '40', '45', '27', '48', '\t?', '52',
#        '14', '22', '18', '42', '17', '46', '23', '19', '25', '41', '26',
#        '15', '21', '43', '20', '\t43', '47', '9', '49', '50', '53', '51',
#        '54'], dtype=object)

# %%
df['pcv'] = pd.to_numeric(df['pcv'], errors = 'coerce' )

# %%
df['pcv'].unique()
# Out:
# array([44., 38., 31., 32., 35., 39., 36., 33., 29., 28., nan, 16., 24.,
#        37., 30., 34., 40., 45., 27., 48., 52., 14., 22., 18., 42., 17.,
#        46., 23., 19., 25., 41., 26., 15., 21., 43., 20., 47.,  9., 49.,
#        50., 53., 51., 54.])

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df['wc'] = pd.to_numeric(df['wc'], errors = 'coerce')
df['rc'] = pd.to_numeric(df['rc'], errors = 'coerce')

# %%
df['wc']
# Out:
# 0      7800.0
# 1      6000.0
# 2      7500.0
# 3      6700.0
# 4      7300.0
#         ...
# 395    6700.0
# 396    7800.0
# 397    6600.0
# 398    7200.0
# 399    6800.0
# Name: wc, Length: 400, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400 entries, 0 to 399
# Data columns (total 25 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             391 non-null    float64
#  1   bp              388 non-null    float64
#  2   sg              353 non-null    float64
#  3   al              354 non-null    float64
#  4   su              351 non-null    float64
#  5   rbc             248 non-null    object
#  6   pc              335 non-null    object
#  7   pcc             396 non-null    object
#  8   ba              396 non-null    object
#  9   bgr             356 non-null    float64
#  10  bu              381 non-null    float64
#  11  sc              383 non-null    float64
#  12  sod             313 non-null    float64
#  13  pot             312 non-null    float64
#  14  hemo            348 non-null    float64
#  15  pcv             329 non-null    float64
#  16  wc              294 non-null    float64
# ...

# %%
cat_col = []
num_col = []
for col in df.columns:
    if df[col].dtype == 'object':
        cat_col.append(col)
    else:
        num_col.append(col)

# %%
cat_col
# Out:
# ['rbc',
#  'pc',
#  'pcc',
#  'ba',
#  'htn',
#  'dm',
#  'cad',
#  'appet',
#  'pe',
#  'ane',
#  'classification']

# %%
num_col
# Out:
# ['age',
#  'bp',
#  'sg',
#  'al',
#  'su',
#  'bgr',
#  'bu',
#  'sc',
#  'sod',
#  'pot',
#  'hemo',
#  'pcv',
#  'wc',
#  'rc']

# %%
for col in cat_col:
    print(f'{col} has ', df[col].unique())
# Out:
# rbc has  [nan 'normal' 'abnormal']
# pc has  ['normal' 'abnormal' nan]
# pcc has  ['notpresent' 'present' nan]
# ba has  ['notpresent' 'present' nan]
# htn has  ['yes' 'no' nan]
# dm has  ['yes' 'no' ' yes' '\tno' '\tyes' nan]
# cad has  ['no' 'yes' '\tno' nan]
# appet has  ['good' 'poor' nan]
# pe has  ['no' 'yes' nan]
# ane has  ['no' 'yes' nan]
# classification has  ['ckd' 'ckd\t' 'notckd']

# %%
df['dm'].replace(to_replace={'yes':'yes',
                             'no':'no',
                             '\tno': 'no',
                             '\tyes': 'yes'}, inplace  = True)

# %%
df['dm'].unique()
# Out:
# array(['yes', 'no', ' yes', nan], dtype=object)

# %%
df.columns
# Out:
# Index(['age', 'bp', 'sg', 'al', 'su', 'rbc', 'pc', 'pcc', 'ba', 'bgr', 'bu',
#        'sc', 'sod', 'pot', 'hemo', 'pcv', 'wc', 'rc', 'htn', 'dm', 'cad',
#        'appet', 'pe', 'ane', 'classification'],
#       dtype='object')

# %%
df['cad'].unique()
# Out:
# array(['no', 'yes', '\tno', nan], dtype=object)

# %%
df['cad'].replace(to_replace={'yes':'yes',
                             'no':'no',
                             '\tno': 'no',
                             '\tyes': 'yes'}, inplace  = True)

# %%
df['cad'].unique()
# Out:
# array(['no', 'yes', nan], dtype=object)

# %%
df['classification'].unique()
# Out:
# array(['ckd', 'ckd\t', 'notckd'], dtype=object)

# %%
df['classification'] = df['classification'].map({'ckd': 1,
                          'notckd': 0,
                          'ckd\t': 1})

# %%
df['classification'].unique()
# Out:
# array([1, 0])

# %%
#Univariate Analysis:

plt.figure(figsize = (10,8))
sns.histplot(df['age'].dropna(), kde = True,color = 'purple', bins = 20)
plt.title("Dist of age")
plt.xlabel("Age")
plt.ylabel('Freequency')
plt.show()
