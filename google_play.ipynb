# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('googleplaystore.csv')

# %%
df.sample(5)
# Out:
#                              App           Category  Rating Reviews  \
# 2276            Visual Anatomy 2            MEDICAL     4.4     576
# 7117                   C.B. Shop           SHOPPING     NaN      19
# 1231                     Cookpad     FOOD_AND_DRINK     4.5  131569
# 74    Tickets SDA 2019 + Exam RF  AUTO_AND_VEHICLES     4.8    7021
# 4318                Daily K-Talk             FAMILY     4.3     264
#
#                     Size     Installs  Type  Price Content Rating  \
# 2276  Varies with device       5,000+  Paid  $2.49       Everyone
# 7117                 19M         100+  Free      0       Everyone
# 1231                8.2M  10,000,000+  Free      0       Everyone
# 74                   17M     500,000+  Free      0       Everyone
# 4318                 60M      10,000+  Free      0       Everyone
#
#                Genres    Last Updated         Current Ver         Android Ver
# 2276          Medical  August 5, 2017  Varies with device  Varies with device
# ...

# %%
df.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df.shape
# Out:
# (10841, 13)

# %%
df.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
df.describe(include = "all")
# Out:
#            App Category       Rating Reviews                Size    Installs  \
# count    10841    10841  9367.000000   10841               10841       10841
# unique    9660       34          NaN    6002                 462          22
# top     ROBLOX   FAMILY          NaN       0  Varies with device  1,000,000+
# freq         9     1972          NaN     596                1695        1579
# mean       NaN      NaN     4.193338     NaN                 NaN         NaN
# std        NaN      NaN     0.537431     NaN                 NaN         NaN
# min        NaN      NaN     1.000000     NaN                 NaN         NaN
# 25%        NaN      NaN     4.000000     NaN                 NaN         NaN
# 50%        NaN      NaN     4.300000     NaN                 NaN         NaN
# 75%        NaN      NaN     4.500000     NaN                 NaN         NaN
# max        NaN      NaN    19.000000     NaN                 NaN         NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df.sample(1)
# Out:
#               App Category  Rating  Reviews Size      Installs  Type Price  \
# 2004  Score! Hero     GAME     4.6  5419676  96M  100,000,000+  Free     0
#
#      Content Rating  Genres   Last Updated Current Ver Android Ver
# 2004       Everyone  Sports  June 13, 2018       1.751  4.4 and up

# %%
#check the number of duplicate rows in the dataset
df.duplicated().sum()
# Out:
# 483

# %%
#Remove duplicate rows from the dataset
df.drop_duplicates(inplace = True)

# %%
#checking for duplicates after removing duplicates
df.duplicated().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews            object
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df['Content Rating'].dtypes
# Out:
# dtype('O')

# %%
df['Reviews'].dtypes
# Out:
# dtype('O')

# %%
df['Reviews']
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10358, dtype: object

# %%
df['Reviews'].unique()
# Out:
# array(['159', '967', '87510', ..., '603', '1195', '398307'], dtype=object)

# %%
#it is possible that the reviews column has some non-numeric values. 
# We can check for that by using the following code:

# Check for non-numeric values in the 'Reviews' column

df[~df['Reviews'].str.isnumeric()]
# Out:
#                                            App Category  Rating Reviews  \
# 10472  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#          Size Installs Type     Price Content Rating             Genres  \
# 10472  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#       Last Updated Current Ver Android Ver
# 10472       1.0.19  4.0 and up         NaN

# %%
df.Reviews
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10836        38
# 10837         4
# 10838         3
# 10839       114
# 10840    398307
# Name: Reviews, Length: 10358, dtype: object

# %%
df_copy = df.copy()
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#resetting the index of the dataframe

df_copy.reset_index(drop = True, inplace = True)

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy[~df_copy['Reviews'].str.isnumeric()]
# Out:
#                                           App Category  Rating Reviews  \
# 9990  Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0    3.0M
#
#         Size Installs Type     Price Content Rating             Genres  \
# 9990  1,000+     Free    0  Everyone            NaN  February 11, 2018
#
#      Last Updated Current Ver Android Ver
# 9990       1.0.19  4.0 and up         NaN

# %%
#drop the row with index 9990
df_copy.drop(index = 9990)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy.Reviews
# Out:
# 0           159
# 1           967
# 2         87510
# 3        215644
# 4           967
#           ...
# 10353        38
# 10354         4
# 10355         3
# 10356       114
# 10357    398307
# Name: Reviews, Length: 10358, dtype: object

# %%
# Safely convert 'Reviews' to numeric:
# 1. Ensure string type, remove commas/whitespace
# 2. Coerce non-convertible values to NaN to avoid ValueError
df_copy['Reviews'] = df_copy['Reviews'].astype(str).str.replace(',', '').str.strip()
df_copy['Reviews'] = pd.to_numeric(df_copy['Reviews'], errors='coerce')

# Optionally: inspect rows that failed conversion and drop them if desired
# print(df_copy[df_copy['Reviews'].isna()])
# df_copy.dropna(subset=['Reviews'], inplace=True)
# df_copy.reset_index(drop=True, inplace=True)

# %%
df_copy.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews           float64
# Size               object
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df_copy['Size'].unique()
# Out:
# array(['19M', '14M', '8.7M', '25M', '2.8M', '5.6M', '29M', '33M', '3.1M',
#        '28M', '12M', '20M', '21M', '37M', '2.7M', '5.5M', '17M', '39M',
#        '31M', '4.2M', '7.0M', '23M', '6.0M', '6.1M', '4.6M', '9.2M',
#        '5.2M', '11M', '24M', 'Varies with device', '9.4M', '15M', '10M',
#        '1.2M', '26M', '8.0M', '7.9M', '56M', '57M', '35M', '54M', '201k',
#        '3.6M', '5.7M', '8.6M', '2.4M', '27M', '2.5M', '16M', '3.4M',
#        '8.9M', '3.9M', '2.9M', '38M', '32M', '5.4M', '18M', '1.1M',
#        '2.2M', '4.5M', '9.8M', '52M', '9.0M', '6.7M', '30M', '2.6M',
#        '7.1M', '3.7M', '22M', '7.4M', '6.4M', '3.2M', '8.2M', '9.9M',
#        '4.9M', '9.5M', '5.0M', '5.9M', '13M', '73M', '6.8M', '3.5M',
#        '4.0M', '2.3M', '7.2M', '2.1M', '42M', '7.3M', '9.1M', '55M',
#        '23k', '6.5M', '1.5M', '7.5M', '51M', '41M', '48M', '8.5M', '46M',
#        '8.3M', '4.3M', '4.7M', '3.3M', '40M', '7.8M', '8.8M', '6.6M',
# ...

# %%
#convert the 'Size' column to numeric values in megabytes (MB)

def convert_size(size):
    if size == 'Varies with device':
        return np.nan
    elif size.endswith('M'):
        return float(size[:-1])
    elif size.endswith('k'):
        return float(size[:-1]) / 1024
    else:
        return np.nan
df_copy['Size'] = df_copy['Size'].apply(convert_size)

# %%
df_copy.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews           float64
# Size              float64
# Installs           object
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df_copy['Size'].unique
# Out:
# <bound method Series.unique of 0        19.0
# 1        14.0
# 2         8.7
# 3        25.0
# 4         2.8
#          ...
# 10353    53.0
# 10354     3.6
# 10355     9.5
# 10356     NaN
# 10357    19.0
# Name: Size, Length: 10358, dtype: float64>

# %%
df_copy['Installs'].unique()
# Out:
# array(['10,000+', '500,000+', '5,000,000+', '50,000,000+', '100,000+',
#        '50,000+', '1,000,000+', '10,000,000+', '5,000+', '100,000,000+',
#        '1,000,000,000+', '1,000+', '500,000,000+', '50+', '100+', '500+',
#        '10+', '1+', '5+', '0+', '0', 'Free'], dtype=object)

# %%
#install column to numeric
df_copy['Installs'] = df_copy['Installs'].str.replace('+', '').str.replace(',', '')
df_copy['Installs'] = pd.to_numeric(df_copy['Installs'], errors='coerce')

# %%
df_copy.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews           float64
# Size              float64
# Installs          float64
# Type               object
# Price              object
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df['Price'].unique()
# Out:
# array(['0', '$4.99', '$3.99', '$6.99', '$1.49', '$2.99', '$7.99', '$5.99',
#        '$3.49', '$1.99', '$9.99', '$7.49', '$0.99', '$9.00', '$5.49',
#        '$10.00', '$24.99', '$11.99', '$79.99', '$16.99', '$14.99',
#        '$1.00', '$29.99', '$12.99', '$2.49', '$10.99', '$1.50', '$19.99',
#        '$15.99', '$33.99', '$74.99', '$39.99', '$3.95', '$4.49', '$1.70',
#        '$8.99', '$2.00', '$3.88', '$25.99', '$399.99', '$17.99',
#        '$400.00', '$3.02', '$1.76', '$4.84', '$4.77', '$1.61', '$2.50',
#        '$1.59', '$6.49', '$1.29', '$5.00', '$13.99', '$299.99', '$379.99',
#        '$37.99', '$18.99', '$389.99', '$19.90', '$8.49', '$1.75',
#        '$14.00', '$4.85', '$46.99', '$109.99', '$154.99', '$3.08',
#        '$2.59', '$4.80', '$1.96', '$19.40', '$3.90', '$4.59', '$15.46',
#        '$3.04', '$4.29', '$2.60', '$3.28', '$4.60', '$28.99', '$2.95',
#        '$2.90', '$1.97', '$200.00', '$89.99', '$2.56', '$30.99', '$3.61',
# ...

# %%
#convert price column to numeric
df_copy['Price'] = df_copy['Price'].str.replace('$', '')
df_copy['Price'] = pd.to_numeric(df_copy['Price'], errors='coerce')

# %%
df_copy.dtypes
# Out:
# App                object
# Category           object
# Rating            float64
# Reviews           float64
# Size              float64
# Installs          float64
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
df['Last Updated']
# Out:
# 0         January 7, 2018
# 1        January 15, 2018
# 2          August 1, 2018
# 3            June 8, 2018
# 4           June 20, 2018
#                ...
# 10836       July 25, 2017
# 10837        July 6, 2018
# 10838    January 20, 2017
# 10839    January 19, 2015
# 10840       July 25, 2018
# Name: Last Updated, Length: 10358, dtype: object

# %%
df['Last Updated'].unique()
# Out:
# array(['January 7, 2018', 'January 15, 2018', 'August 1, 2018', ...,
#        'January 20, 2014', 'February 16, 2014', 'March 23, 2014'],
#       dtype=object)

# %%
#last updated column to datetime
df_copy['Last Updated'] = pd.to_datetime(df_copy['Last Updated'], errors='coerce')

# %%
df_copy['Last Updated'].unique()
# Out:
# <DatetimeArray>
# ['2018-01-07 00:00:00', '2018-01-15 00:00:00', '2018-08-01 00:00:00',
#  '2018-06-08 00:00:00', '2018-06-20 00:00:00', '2017-03-26 00:00:00',
#  '2018-04-26 00:00:00', '2018-06-14 00:00:00', '2017-09-20 00:00:00',
#  '2018-07-03 00:00:00',
#  ...
#  '2015-11-23 00:00:00', '2012-06-17 00:00:00', '2015-02-27 00:00:00',
#  '2013-12-18 00:00:00', '2012-02-06 00:00:00', '2014-11-25 00:00:00',
#  '2016-05-19 00:00:00', '2014-01-20 00:00:00', '2014-02-16 00:00:00',
#  '2014-03-23 00:00:00']
# Length: 1378, dtype: datetime64[ns]

# %%
df_copy['Android Ver'].unique()
# Out:
# array(['4.0.3 and up', '4.2 and up', '4.4 and up', '2.3 and up',
#        '3.0 and up', '4.1 and up', '4.0 and up', '2.3.3 and up',
#        'Varies with device', '2.2 and up', '5.0 and up', '6.0 and up',
#        '1.6 and up', '1.5 and up', '2.1 and up', '7.0 and up',
#        '5.1 and up', '4.3 and up', '4.0.3 - 7.1.1', '2.0 and up',
#        '3.2 and up', '4.4W and up', '7.1 and up', '7.0 - 7.1.1',
#        '8.0 and up', '5.0 - 8.0', '3.1 and up', '2.0.1 and up',
#        '4.1 - 7.1.1', nan, '5.0 - 6.0', '1.0 and up', '2.2 - 7.1.1',
#        '5.0 - 7.1.1'], dtype=object)

# %%
df_copy['App'].unique()
# Out:
# array(['Photo Editor & Candy Camera & Grid & ScrapBook',
#        'Coloring book moana',
#        'U Launcher Lite – FREE Live Cool Themes, Hide Apps', ...,
#        'Parkinson Exercices FR', 'The SCP Foundation DB fr nn5n',
#        'iHoroscope - 2018 Daily Horoscope & Astrology'], dtype=object)

# %%
df_copy['App'].duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10353    False
# 10354    False
# 10355    False
# 10356    False
# 10357    False
# Name: App, Length: 10358, dtype: bool

# %%
df_copy.drop_duplicates(subset = 'App', inplace = True, keep = 'first')

# %%
df_copy.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 10353    False
# 10354    False
# 10355    False
# 10356    False
# 10357    False
# Length: 9660, dtype: bool

# %%
df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df_copy
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
df_copy.describe()
# Out:
#             Rating       Reviews         Size      Installs        Price  \
# count  8197.000000  9.659000e+03  8432.000000  9.659000e+03  9659.000000
# mean      4.175052  2.165926e+05    20.394897  7.777507e+06     1.099299
# min       1.000000  0.000000e+00     0.008301  0.000000e+00     0.000000
# 25%       4.000000  2.500000e+01     4.600000  1.000000e+03     0.000000
# 50%       4.300000  9.670000e+02    12.000000  1.000000e+05     0.000000
# 75%       4.500000  2.940100e+04    28.000000  1.000000e+06     0.000000
# max      19.000000  7.815831e+07   100.000000  1.000000e+09   400.000000
# std       0.561026  1.831320e+06    21.827898  5.375828e+07    16.852152
#
#                         Last Updated
# count                           9659
# mean   2017-10-30 19:34:02.074748928
# min              2010-05-21 00:00:00
# 25%              2017-08-05 12:00:00
# 50%              2018-05-04 00:00:00
# 75%              2018-07-17 00:00:00
# max              2018-08-08 00:00:00
# ...

# %%
df_copy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9660 entries, 0 to 10357
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             9660 non-null   object
#  1   Category        9660 non-null   object
#  2   Rating          8197 non-null   float64
#  3   Reviews         9659 non-null   float64
#  4   Size            8432 non-null   float64
#  5   Installs        9659 non-null   float64
#  6   Type            9659 non-null   object
#  7   Price           9659 non-null   float64
#  8   Content Rating  9659 non-null   object
#  9   Genres          9660 non-null   object
#  10  Last Updated    9659 non-null   datetime64[ns]
#  11  Current Ver     9652 non-null   object
#  12  Android Ver     9657 non-null   object
# dtypes: datetime64[ns](1), float64(5), object(7)
# memory usage: 1.0+ MB

# %%
df_copy.duplicated(subset = 'App').sum()
# Out:
# 0

# %%
# EDA and Visualization

# %%
categorial_cols = df_copy.select_dtypes(include = 'object').columns
print(categorial_cols)
# Out:
# Index(['App', 'Category', 'Type', 'Content Rating', 'Genres', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
numeric_cols = df_copy.select_dtypes(include = 'number').columns
print(numeric_cols)
# Out:
# Index(['Rating', 'Reviews', 'Size', 'Installs', 'Price'], dtype='object')

# %%
# EDA depend on the type of data in the columns. 
# For example, we can plot the distribution of the 'Rating' column using a histogram:

# %%
df_copy[categorial_cols]
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10353                                   Sya9a Maroc - FR               FAMILY
# 10354                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10355                             Parkinson Exercices FR              MEDICAL
# 10356                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10357      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
# ...

# %%
#Categorical columns we can make , bar plots, pie charts,histogram,linechart,pairplot, count plots, etc.

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_copy['Type'].value_counts()
# Out:
# Type
# Free    8902
# Paid     756
# 0          1
# Name: count, dtype: int64

# %%
for col in categorial_cols:
    print(f"Value counts for {col}:")
    print(df_copy[col].value_counts())
    print("\n")
# Out:
# Value counts for App:
# App
# Photo Editor & Candy Camera & Grid & ScrapBook    1
# CK Pharmacies                                     1
# CK Call NEW                                       1
# Ck Coif                                           1
# CONTRACT KILLER: ZOMBIES                          1
#                                                  ..
# Bike Race Free - Top Motorcycle Racing Games      1
# Dance School Stories - Dance Dreams Come True     1
# 3D Bowling                                        1
# Mind Games Pro                                    1
# iHoroscope - 2018 Daily Horoscope & Astrology     1
# Name: count, Length: 9660, dtype: int64
#
#
# Value counts for Category:
# Category
# FAMILY                 1832
# GAME                    959
# TOOLS                   827
# BUSINESS                420
# MEDICAL                 395
# PERSONALIZATION         376
# PRODUCTIVITY            374
# LIFESTYLE               369
# FINANCE                 345
# ...

# %%
#Plot for the distribution of the 'Rating' column

df_copy['Type'].value_counts().plot(kind = 'bar')
plt.title('Distribution of App Types')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %%
sns.countplot(x = 'Type', data = df_copy)
plt.title('Distribution of App Types')
plt.xlabel('Type')
plt.ylabel('Count')
plt.show()

# %%
# numerical columns we can make , histogram, boxplot, scatter plot, pairplot, etc.

numerical_cols = ['Rating', 'Reviews', 'Installs', 'Price']
for col in numerical_cols:
    plt.figure(figsize=(8, 4))
    sns.histplot(df_copy[col].dropna(), kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(20,8))
category = ["Type", "Content Rating"]
for i in range(len(category)):
    ax = plt.subplot(1, 2, i+1)
    sns.countplot(x=category[i], data=df_copy, ax=ax)
    ax.set_title(f'Distribution of {category[i]}')
    ax.set_xlabel(category[i])
    ax.set_ylabel('Count')
plt.tight_layout()
plt.show()

# %%
# which category is the most popular category in the app ?
# value_counts() returns a Series, so plot the pie directly.
df_copy['Category'].value_counts().plot.pie(figsize=(8,8), autopct='%.1f%%')
plt.title('Most Popular App Categories')
plt.ylabel('')  # hide automatic ylabel
plt.show()

# %%
# Family App has most popular with 19% of the share

# %%
# top 10 category:

cat = df['Category'].value_counts()[:10]
cat
# Out:
# Category
# FAMILY             1943
# GAME               1121
# TOOLS               843
# BUSINESS            427
# MEDICAL             408
# PRODUCTIVITY        407
# PERSONALIZATION     388
# LIFESTYLE           373
# COMMUNICATION       366
# FINANCE             360
# Name: count, dtype: int64

# %%
top10 = cat.reset_index()
top10
# Out:
#           Category  count
# 0           FAMILY   1943
# 1             GAME   1121
# 2            TOOLS    843
# 3         BUSINESS    427
# 4          MEDICAL    408
# 5     PRODUCTIVITY    407
# 6  PERSONALIZATION    388
# 7        LIFESTYLE    373
# 8    COMMUNICATION    366
# 9          FINANCE    360

# %%
top10.columns = ['Groups','counts']
top10
# Out:
#             Groups  counts
# 0           FAMILY    1943
# 1             GAME    1121
# 2            TOOLS     843
# 3         BUSINESS     427
# 4          MEDICAL     408
# 5     PRODUCTIVITY     407
# 6  PERSONALIZATION     388
# 7        LIFESTYLE     373
# 8    COMMUNICATION     366
# 9          FINANCE     360

# %%
sns.barplot(top10,x = top10['Groups'],y = top10['counts'])
# Out:
# <Axes: xlabel='Groups', ylabel='counts'>

# %%
#which category has the highest Installations.


df_copy.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
df_copy.groupby(['Category'])["Installs"].sum().sort_values(ascending=False).reset_index()
# Out:
#                Category      Installs
# 0                  GAME  1.387892e+10
# 1         COMMUNICATION  1.103828e+10
# 2                 TOOLS  8.001772e+09
# 3          PRODUCTIVITY  5.793091e+09
# 4                SOCIAL  5.487868e+09
# 5           PHOTOGRAPHY  4.649148e+09
# 6                FAMILY  4.427942e+09
# 7         VIDEO_PLAYERS  3.926903e+09
# 8      TRAVEL_AND_LOCAL  2.894887e+09
# 9    NEWS_AND_MAGAZINES  2.369218e+09
# 10        ENTERTAINMENT  2.113660e+09
# 11  BOOKS_AND_REFERENCE  1.665970e+09
# 12      PERSONALIZATION  1.532495e+09
# 13             SHOPPING  1.400349e+09
# 14   HEALTH_AND_FITNESS  1.144023e+09
# 15               SPORTS  1.096474e+09
# 16             BUSINESS  6.971649e+08
# 17            LIFESTYLE  5.038235e+08
# 18  MAPS_AND_NAVIGATION  5.032819e+08
# 19              FINANCE  4.553487e+08
# 20              WEATHER  3.611005e+08
# 21            EDUCATION  3.529520e+08
# 22       FOOD_AND_DRINK  2.117988e+08
# 23               DATING  1.409261e+08
# ...

# %%
sns.boxplot(df_copy['Rating'])
# Out:
# <Axes: ylabel='Rating'>

# %%
sns.boxplot(x = "Installs",y = "Rating", data = df_copy)
# Out:
# <Axes: xlabel='Installs', ylabel='Rating'>
